# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # type: ignore

# %%
df = pd.read_csv(r'C:\Users\Acer\Documents\datasets for ml\gym_members_exercise_tracking.csv')
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
A=df.iloc[:,2:4]
B=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
A_train, A_test,B_train, B_test = train_test_split(A,B,test_size=0.25,random_state=104)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
reg_bmi = LinearRegression()
reg_bmi.fit(A, B)
# Out:
# LinearRegression()

# %%
reg_bmi.score(A_train,B_train)
# Out:
# 0.9840439904714595

# %%
reg_bmi.predict([[88.3	,1.71]])
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([30.0407903])

# %%
import pickle
pickle.dump(reg_bmi,open('model_save','wb'))
model=pickle.load(open('model_save','rb'))
model.predict([[72,1.62]])
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([27.20815127])
